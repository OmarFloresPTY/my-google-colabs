# %% [markdown]
# <a href="https://colab.research.google.com/github/OmarFloresPTY/my-google-colabs/blob/master/02_Pandas_annotations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10 minutes to pandas 🐼📚🐍

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Object Creation

# %%
s = pd.Series([1,3,4,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    4.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101',periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD')) #np.random.randn(fila,columna) genera una matriz fila x columna de 0 y una desviación estándar de 1
# Out:
#                    A         B         C         D
# 2013-01-01  0.494200 -0.025161  2.316596  0.055902
# 2013-01-02 -1.143214  0.456303 -1.134004  0.530386
# 2013-01-03  0.120991  0.663819  0.708184 -0.219082
# 2013-01-04 -0.143476  0.605036 -1.119808  1.443138
# 2013-01-05 -0.519936  1.152605  1.139425  1.568212
# 2013-01-06  1.119840  1.447411  0.460106  0.406254

# %%
pd.DataFrame(np.random.randint(0,20,size=(5,5)),index=[i for i in range(5,10)],columns=['A','B','C','D','E'])
# Out:
#     A   B   C   D   E
# 5  15  11  17  12   9
# 6   5  19   7   1  18
# 7  14   7   8   1   7
# 8  17   5  18   1  10
# 9  18   7  10  14   8

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# ## Viewing Data

# %%
index = pd.date_range("1/1/2000", periods=8)
df = pd.DataFrame(np.random.randn(8, 3), index=index, columns=["A", "B", "C"])
df
# Out:
#                    A         B         C
# 2000-01-01 -0.878105 -2.998879  0.401435
# 2000-01-02  0.358286  0.493555 -0.735156
# 2000-01-03 -0.240936 -0.873235 -0.532821
# 2000-01-04  0.144077  1.264866 -1.052614
# 2000-01-05  1.528870 -0.864696  1.183935
# 2000-01-06 -1.274869 -0.327925 -0.694429
# 2000-01-07  0.615503  1.678456  1.406838
# 2000-01-08  0.520235 -1.954525  0.099986

# %%
df.head()
# Out:
#                    A         B         C
# 2000-01-01  1.437714  0.978269 -0.852123
# 2000-01-02  0.599530  1.720559  0.165558
# 2000-01-03 -0.458938  0.103245 -1.414177
# 2000-01-04  2.151158  0.728884  0.387090
# 2000-01-05 -0.471901  0.829917  0.565856

# %%
df.tail(3)
# Out:
#                    A         B         C
# 2000-01-06 -0.281434 -1.489610  0.065633
# 2000-01-07 -1.095357  0.722598  2.333382
# 2000-01-08 -0.821078  0.068622  0.589928

# %%
df.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %% [markdown]
# ¡IMPORTANTE! 🚨 La conversión de un dataFrame a un objeto numpy, NO incluye los índices o columnas.

# %%
df.to_numpy()
# Out:
# array([[ 1.4377139 ,  0.97826869, -0.85212301],
#        [ 0.59953041,  1.72055869,  0.16555775],
#        [-0.45893824,  0.10324478, -1.41417665],
#        [ 2.15115827,  0.72888354,  0.38709043],
#        [-0.47190133,  0.82991693,  0.5658557 ],
#        [-0.28143442, -1.48960972,  0.06563258],
#        [-1.09535679,  0.72259798,  2.33338179],
#        [-0.82107831,  0.06862243,  0.58992816]])

# %%
print(type(df))
print(type(df.to_numpy()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C
# count  8.000000  8.000000  8.000000
# mean   0.132462  0.457810  0.230143
# std    1.152641  0.942421  1.108198
# min   -1.095357 -1.489610 -1.414177
# 25%   -0.559196  0.094589 -0.163806
# 50%   -0.370186  0.725741  0.276324
# 75%    0.809076  0.867005  0.571874
# max    2.151158  1.720559  2.333382

# %%
df.T
# Out:
#    2000-01-01  2000-01-02  2000-01-03  2000-01-04  2000-01-05  2000-01-06  \
# A    1.437714    0.599530   -0.458938    2.151158   -0.471901   -0.281434
# B    0.978269    1.720559    0.103245    0.728884    0.829917   -1.489610
# C   -0.852123    0.165558   -1.414177    0.387090    0.565856    0.065633
#
#    2000-01-07  2000-01-08
# A   -1.095357   -0.821078
# B    0.722598    0.068622
# C    2.333382    0.589928

# %%
df
# Out:
#                    A         B         C
# 2000-01-01  1.437714  0.978269 -0.852123
# 2000-01-02  0.599530  1.720559  0.165558
# 2000-01-03 -0.458938  0.103245 -1.414177
# 2000-01-04  2.151158  0.728884  0.387090
# 2000-01-05 -0.471901  0.829917  0.565856
# 2000-01-06 -0.281434 -1.489610  0.065633
# 2000-01-07 -1.095357  0.722598  2.333382
# 2000-01-08 -0.821078  0.068622  0.589928

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                    C         B         A
# 2000-01-01 -0.852123  0.978269  1.437714
# 2000-01-02  0.165558  1.720559  0.599530
# 2000-01-03 -1.414177  0.103245 -0.458938
# 2000-01-04  0.387090  0.728884  2.151158
# 2000-01-05  0.565856  0.829917 -0.471901
# 2000-01-06  0.065633 -1.489610 -0.281434
# 2000-01-07  2.333382  0.722598 -1.095357
# 2000-01-08  0.589928  0.068622 -0.821078

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C
# 2000-01-06 -0.281434 -1.489610  0.065633
# 2000-01-08 -0.821078  0.068622  0.589928
# 2000-01-03 -0.458938  0.103245 -1.414177
# 2000-01-07 -1.095357  0.722598  2.333382
# 2000-01-04  2.151158  0.728884  0.387090
# 2000-01-05 -0.471901  0.829917  0.565856
# 2000-01-01  1.437714  0.978269 -0.852123
# 2000-01-02  0.599530  1.720559  0.165558

# %% [markdown]
# ## Getting
# Selecting a single column, which yields a Series.

# %%
df
# Out:
#                    A         B         C
# 2000-01-01 -0.878105 -2.998879  0.401435
# 2000-01-02  0.358286  0.493555 -0.735156
# 2000-01-03 -0.240936 -0.873235 -0.532821
# 2000-01-04  0.144077  1.264866 -1.052614
# 2000-01-05  1.528870 -0.864696  1.183935
# 2000-01-06 -1.274869 -0.327925 -0.694429
# 2000-01-07  0.615503  1.678456  1.406838
# 2000-01-08  0.520235 -1.954525  0.099986

# %%
df['A']
# Out:
# 2000-01-01   -0.878105
# 2000-01-02    0.358286
# 2000-01-03   -0.240936
# 2000-01-04    0.144077
# 2000-01-05    1.528870
# 2000-01-06   -1.274869
# 2000-01-07    0.615503
# 2000-01-08    0.520235
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C
# 2000-01-01 -0.878105 -2.998879  0.401435
# 2000-01-02  0.358286  0.493555 -0.735156
# 2000-01-03 -0.240936 -0.873235 -0.532821

# %% [markdown]
# ## Selection by label

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2000-01-01 -0.878105 -2.998879
# 2000-01-02  0.358286  0.493555
# 2000-01-03 -0.240936 -0.873235
# 2000-01-04  0.144077  1.264866
# 2000-01-05  1.528870 -0.864696
# 2000-01-06 -1.274869 -0.327925
# 2000-01-07  0.615503  1.678456
# 2000-01-08  0.520235 -1.954525

# %%
df.loc["20000101":"20000104", ["A", "B"]]
# Out:
#                    A         B
# 2000-01-01 -0.878105 -2.998879
# 2000-01-02  0.358286  0.493555
# 2000-01-03 -0.240936 -0.873235
# 2000-01-04  0.144077  1.264866

# %%
index[0]
# Out:
# Timestamp('2000-01-01 00:00:00', freq='D')

# %%
df.loc[index[0],"A"]
# Out:
# -0.878105202541449

# %%
df.at[index[0],"A"] #Exactamente igual pero más rápido en memoria.
# Out:
# -0.878105202541449

# %% [markdown]
# ##Selection by position

# %%
df
# Out:
#                    A         B         C
# 2000-01-01 -0.878105 -2.998879  0.401435
# 2000-01-02  0.358286  0.493555 -0.735156
# 2000-01-03 -0.240936 -0.873235 -0.532821
# 2000-01-04  0.144077  1.264866 -1.052614
# 2000-01-05  1.528870 -0.864696  1.183935
# 2000-01-06 -1.274869 -0.327925 -0.694429
# 2000-01-07  0.615503  1.678456  1.406838
# 2000-01-08  0.520235 -1.954525  0.099986

# %%
df.iloc[3] ##Accede al registro de la posición 3 en el dataFrame
# Out:
# A    0.144077
# B    1.264866
# C   -1.052614
# Name: 2000-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2] #Primer slice son filas, segundo slice son columnas
# Out:
#                    A         B
# 2000-01-04  0.144077  1.264866
# 2000-01-05  1.528870 -0.864696

# %%
df.iloc[[1,2,4],[0,2]] #Filtrando por índices específicos
# Out:
#                    A         C
# 2000-01-02  0.358286 -0.735156
# 2000-01-03 -0.240936 -0.532821
# 2000-01-05  1.528870  1.183935

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C
# 2000-01-02  0.358286  0.493555 -0.735156
# 2000-01-03 -0.240936 -0.873235 -0.532821

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2000-01-01 -2.998879  0.401435
# 2000-01-02  0.493555 -0.735156
# 2000-01-03 -0.873235 -0.532821
# 2000-01-04  1.264866 -1.052614
# 2000-01-05 -0.864696  1.183935
# 2000-01-06 -0.327925 -0.694429
# 2000-01-07  1.678456  1.406838
# 2000-01-08 -1.954525  0.099986

# %%
df.iloc[1,1]
# Out:
# 0.4935545440006357

# %%
df.iat[1,1]
# Out:
# 0.4935545440006357

# %% [markdown]
# ##Boolean indexing

# %%
df[df['A'] > 0.5]
# Out:
#                    A         B         C
# 2000-01-05  1.528870 -0.864696  1.183935
# 2000-01-07  0.615503  1.678456  1.406838
# 2000-01-08  0.520235 -1.954525  0.099986

# %%
df[df > 0]
# Out:
#                    A         B         C
# 2000-01-01       NaN       NaN  0.401435
# 2000-01-02  0.358286  0.493555       NaN
# 2000-01-03       NaN       NaN       NaN
# 2000-01-04  0.144077  1.264866       NaN
# 2000-01-05  1.528870       NaN  1.183935
# 2000-01-06       NaN       NaN       NaN
# 2000-01-07  0.615503  1.678456  1.406838
# 2000-01-08  0.520235       NaN  0.099986

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three","four", "three"]
df2
# Out:
#                    A         B         C      E
# 2000-01-01 -0.878105 -2.998879  0.401435    one
# 2000-01-02  0.358286  0.493555 -0.735156    one
# 2000-01-03 -0.240936 -0.873235 -0.532821    two
# 2000-01-04  0.144077  1.264866 -1.052614  three
# 2000-01-05  1.528870 -0.864696  1.183935   four
# 2000-01-06 -1.274869 -0.327925 -0.694429  three
# 2000-01-07  0.615503  1.678456  1.406838   four
# 2000-01-08  0.520235 -1.954525  0.099986  three

# %%
df2[df2["E"].isin(["two","four"])] #El método isin() funciona para filtrar también.
# Out:
#                    A         B         C     E
# 2000-01-03 -0.240936 -0.873235 -0.532821   two
# 2000-01-05  1.528870 -0.864696  1.183935  four
# 2000-01-07  0.615503  1.678456  1.406838  four

# %% [markdown]
# ## Setting
