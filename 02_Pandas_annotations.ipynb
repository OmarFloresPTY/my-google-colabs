# %% [markdown]
# <a href="https://colab.research.google.com/github/OmarFloresPTY/my-google-colabs/blob/master/02_Pandas_annotations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10 minutes to pandas 🐼📚🐍

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Object Creation

# %%
s = pd.Series([1,3,4,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    4.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101',periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD')) #np.random.randn(fila,columna) genera una matriz fila x columna de 0 y una desviación estándar de 1
# Out:
#                    A         B         C         D
# 2013-01-01  0.494200 -0.025161  2.316596  0.055902
# 2013-01-02 -1.143214  0.456303 -1.134004  0.530386
# 2013-01-03  0.120991  0.663819  0.708184 -0.219082
# 2013-01-04 -0.143476  0.605036 -1.119808  1.443138
# 2013-01-05 -0.519936  1.152605  1.139425  1.568212
# 2013-01-06  1.119840  1.447411  0.460106  0.406254

# %%
pd.DataFrame(np.random.randint(0,20,size=(5,5)),index=[i for i in range(5,10)],columns=['A','B','C','D','E'])
# Out:
#     A   B   C   D   E
# 5  15  11  17  12   9
# 6   5  19   7   1  18
# 7  14   7   8   1   7
# 8  17   5  18   1  10
# 9  18   7  10  14   8

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# ## Viewing Data

# %%
index = pd.date_range("1/1/2000", periods=8)
df = pd.DataFrame(np.random.randn(8, 3), index=index, columns=["A", "B", "C"])
df
# Out:
#                    A         B         C
# 2000-01-01  0.966314  0.931645  0.303348
# 2000-01-02 -2.205841  0.202679  1.066221
# 2000-01-03 -1.185118  0.649188 -0.422109
# 2000-01-04 -0.567090 -0.104624 -0.856980
# 2000-01-05 -0.000358 -1.666904  0.364500
# 2000-01-06  0.438707 -1.157793 -0.086172
# 2000-01-07  0.821727  1.138478 -0.723475
# 2000-01-08 -0.896600 -1.694298  1.776689

# %%
df.head()
# Out:
#                    A         B         C
# 2000-01-01  0.748659 -1.150961  1.340927
# 2000-01-02  1.753779  0.054245 -0.174204
# 2000-01-03 -0.656894  0.370821  0.250454
# 2000-01-04 -0.464137 -1.970613 -0.473362
# 2000-01-05  0.097053 -0.033579 -0.465060

# %%
df.tail(3)
# Out:
#                    A         B         C
# 2000-01-06  0.462307  0.545508  0.839077
# 2000-01-07 -0.607997  0.210907 -0.563551
# 2000-01-08  0.239716  1.017750 -0.481969

# %%
df.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %% [markdown]
# ¡IMPORTANTE! 🚨 La conversión de un dataFrame a un objeto numpy, NO incluye los índices o columnas.

# %%
df.to_numpy()
# Out:
# array([[ 0.74865878, -1.15096065,  1.3409273 ],
#        [ 1.75377906,  0.05424516, -0.17420374],
#        [-0.65689382,  0.37082057,  0.25045367],
#        [-0.46413663, -1.97061271, -0.47336161],
#        [ 0.09705327, -0.03357883, -0.46506048],
#        [ 0.46230739,  0.5455077 ,  0.83907677],
#        [-0.60799694,  0.21090727, -0.5635506 ],
#        [ 0.23971553,  1.01774995, -0.48196859]])

# %%
print(type(df))
print(type(df.to_numpy()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C
# count  8.000000  8.000000  8.000000
# mean   0.196561 -0.119490  0.034039
# std    0.812786  0.971983  0.714760
# min   -0.656894 -1.970613 -0.563551
# 25%   -0.500102 -0.312924 -0.475513
# 50%    0.168384  0.132576 -0.319632
# 75%    0.533895  0.414492  0.397609
# max    1.753779  1.017750  1.340927

# %%
df.T
# Out:
#    2000-01-01  2000-01-02  2000-01-03  2000-01-04  2000-01-05  2000-01-06  \
# A    0.748659    1.753779   -0.656894   -0.464137    0.097053    0.462307
# B   -1.150961    0.054245    0.370821   -1.970613   -0.033579    0.545508
# C    1.340927   -0.174204    0.250454   -0.473362   -0.465060    0.839077
#
#    2000-01-07  2000-01-08
# A   -0.607997    0.239716
# B    0.210907    1.017750
# C   -0.563551   -0.481969

# %%
df
# Out:
#                    A         B         C
# 2000-01-01  0.748659 -1.150961  1.340927
# 2000-01-02  1.753779  0.054245 -0.174204
# 2000-01-03 -0.656894  0.370821  0.250454
# 2000-01-04 -0.464137 -1.970613 -0.473362
# 2000-01-05  0.097053 -0.033579 -0.465060
# 2000-01-06  0.462307  0.545508  0.839077
# 2000-01-07 -0.607997  0.210907 -0.563551
# 2000-01-08  0.239716  1.017750 -0.481969

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                    C         B         A
# 2000-01-01  1.340927 -1.150961  0.748659
# 2000-01-02 -0.174204  0.054245  1.753779
# 2000-01-03  0.250454  0.370821 -0.656894
# 2000-01-04 -0.473362 -1.970613 -0.464137
# 2000-01-05 -0.465060 -0.033579  0.097053
# 2000-01-06  0.839077  0.545508  0.462307
# 2000-01-07 -0.563551  0.210907 -0.607997
# 2000-01-08 -0.481969  1.017750  0.239716

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C
# 2000-01-04 -0.464137 -1.970613 -0.473362
# 2000-01-01  0.748659 -1.150961  1.340927
# 2000-01-05  0.097053 -0.033579 -0.465060
# 2000-01-02  1.753779  0.054245 -0.174204
# 2000-01-07 -0.607997  0.210907 -0.563551
# 2000-01-03 -0.656894  0.370821  0.250454
# 2000-01-06  0.462307  0.545508  0.839077
# 2000-01-08  0.239716  1.017750 -0.481969

# %% [markdown]
# ## Getting
# Selecting a single column, which yields a Series.

# %%
df
# Out:
#                    A         B         C
# 2000-01-01  0.748659 -1.150961  1.340927
# 2000-01-02  1.753779  0.054245 -0.174204
# 2000-01-03 -0.656894  0.370821  0.250454
# 2000-01-04 -0.464137 -1.970613 -0.473362
# 2000-01-05  0.097053 -0.033579 -0.465060
# 2000-01-06  0.462307  0.545508  0.839077
# 2000-01-07 -0.607997  0.210907 -0.563551
# 2000-01-08  0.239716  1.017750 -0.481969

# %%
df['A']
# Out:
# 2000-01-01    0.748659
# 2000-01-02    1.753779
# 2000-01-03   -0.656894
# 2000-01-04   -0.464137
# 2000-01-05    0.097053
# 2000-01-06    0.462307
# 2000-01-07   -0.607997
# 2000-01-08    0.239716
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C
# 2000-01-01  0.748659 -1.150961  1.340927
# 2000-01-02  1.753779  0.054245 -0.174204
# 2000-01-03 -0.656894  0.370821  0.250454

# %% [markdown]
# ## Selection by label

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2000-01-01  0.748659 -1.150961
# 2000-01-02  1.753779  0.054245
# 2000-01-03 -0.656894  0.370821
# 2000-01-04 -0.464137 -1.970613
# 2000-01-05  0.097053 -0.033579
# 2000-01-06  0.462307  0.545508
# 2000-01-07 -0.607997  0.210907
# 2000-01-08  0.239716  1.017750

# %%
df.loc["20000101":"20000104", ["A", "B"]]
# Out:
#                    A         B
# 2000-01-01  0.748659 -1.150961
# 2000-01-02  1.753779  0.054245
# 2000-01-03 -0.656894  0.370821
# 2000-01-04 -0.464137 -1.970613

# %%
index[0]
# Out:
# Timestamp('2000-01-01 00:00:00', freq='D')

# %%
df.loc[index[0],"A"]
# Out:
# 0.748658778023008

# %%
df.at[index[0],"A"] #Exactamente igual pero más rápido en memoria.
# Out:
# 0.748658778023008

# %% [markdown]
# ##Selection by position

# %%
df
# Out:
#                    A         B         C
# 2000-01-01  0.748659 -1.150961  1.340927
# 2000-01-02  1.753779  0.054245 -0.174204
# 2000-01-03 -0.656894  0.370821  0.250454
# 2000-01-04 -0.464137 -1.970613 -0.473362
# 2000-01-05  0.097053 -0.033579 -0.465060
# 2000-01-06  0.462307  0.545508  0.839077
# 2000-01-07 -0.607997  0.210907 -0.563551
# 2000-01-08  0.239716  1.017750 -0.481969

# %%
df.iloc[3] ##Accede al registro de la posición 3 en el dataFrame
# Out:
# A   -0.464137
# B   -1.970613
# C   -0.473362
# Name: 2000-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2] #Primer slice son filas, segundo slice son columnas
# Out:
#                    A         B
# 2000-01-04 -0.464137 -1.970613
# 2000-01-05  0.097053 -0.033579

# %%
df.iloc[[1,2,4],[0,2]] #Filtrando por índices específicos
# Out:
#                    A         C
# 2000-01-02  1.753779 -0.174204
# 2000-01-03 -0.656894  0.250454
# 2000-01-05  0.097053 -0.465060

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C
# 2000-01-02  1.753779  0.054245 -0.174204
# 2000-01-03 -0.656894  0.370821  0.250454

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2000-01-01 -1.150961  1.340927
# 2000-01-02  0.054245 -0.174204
# 2000-01-03  0.370821  0.250454
# 2000-01-04 -1.970613 -0.473362
# 2000-01-05 -0.033579 -0.465060
# 2000-01-06  0.545508  0.839077
# 2000-01-07  0.210907 -0.563551
# 2000-01-08  1.017750 -0.481969

# %%
df.iloc[1,1]
# Out:
# 0.4935545440006357

# %%
df.iat[1,1]
# Out:
# 0.0542451607868941

# %% [markdown]
# ##Boolean indexing

# %%
df[df['A'] > 0.5]
# Out:
#                    A         B         C
# 2000-01-01  0.748659 -1.150961  1.340927
# 2000-01-02  1.753779  0.054245 -0.174204

# %%
df[df > 0]
# Out:
#                    A         B         C
# 2000-01-01  0.748659       NaN  1.340927
# 2000-01-02  1.753779  0.054245       NaN
# 2000-01-03       NaN  0.370821  0.250454
# 2000-01-04       NaN       NaN       NaN
# 2000-01-05  0.097053       NaN       NaN
# 2000-01-06  0.462307  0.545508  0.839077
# 2000-01-07       NaN  0.210907       NaN
# 2000-01-08  0.239716  1.017750       NaN

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three","four", "three"]
df2
# Out:
#                    A         B         C      E
# 2000-01-01  0.748659 -1.150961  1.340927    one
# 2000-01-02  1.753779  0.054245 -0.174204    one
# 2000-01-03 -0.656894  0.370821  0.250454    two
# 2000-01-04 -0.464137 -1.970613 -0.473362  three
# 2000-01-05  0.097053 -0.033579 -0.465060   four
# 2000-01-06  0.462307  0.545508  0.839077  three
# 2000-01-07 -0.607997  0.210907 -0.563551   four
# 2000-01-08  0.239716  1.017750 -0.481969  three

# %%
df2[df2["E"].isin(["two","four"])] #El método isin() funciona para filtrar también.
# Out:
#                    A         B         C     E
# 2000-01-03 -0.656894  0.370821  0.250454   two
# 2000-01-05  0.097053 -0.033579 -0.465060  four
# 2000-01-07 -0.607997  0.210907 -0.563551  four

# %% [markdown]
# ## Setting

# %%
s1 = pd.Series([1,2,3,4,5,6,7,8],index=pd.date_range("2000-01-01", periods=8))
s1
# Out:
# 2000-01-01    1
# 2000-01-02    2
# 2000-01-03    3
# 2000-01-04    4
# 2000-01-05    5
# 2000-01-06    6
# 2000-01-07    7
# 2000-01-08    8
# Freq: D, dtype: int64

# %%
df["F"] = s1
df
# Out:
#                    A         B         C  F
# 2000-01-01  0.748659 -1.150961  1.340927  1
# 2000-01-02  1.753779  0.054245 -0.174204  2
# 2000-01-03 -0.656894  0.370821  0.250454  3
# 2000-01-04 -0.464137 -1.970613 -0.473362  4
# 2000-01-05  0.097053 -0.033579 -0.465060  5
# 2000-01-06  0.462307  0.545508  0.839077  6
# 2000-01-07 -0.607997  0.210907 -0.563551  7
# 2000-01-08  0.239716  1.017750 -0.481969  8

# %%
df.at[index[0],"A"] = 0
df
# Out:
#                    A         B         C  F
# 2000-01-01  0.000000 -1.150961  1.340927  1
# 2000-01-02  1.753779  0.054245 -0.174204  2
# 2000-01-03 -0.656894  0.370821  0.250454  3
# 2000-01-04 -0.464137 -1.970613 -0.473362  4
# 2000-01-05  0.097053 -0.033579 -0.465060  5
# 2000-01-06  0.462307  0.545508  0.839077  6
# 2000-01-07 -0.607997  0.210907 -0.563551  7
# 2000-01-08  0.239716  1.017750 -0.481969  8

# %%
df.iat[0, 1] = 0
df
# Out:
#                    A         B         C  F
# 2000-01-01  0.000000  0.000000  1.340927  1
# 2000-01-02  1.753779  0.054245 -0.174204  2
# 2000-01-03 -0.656894  0.370821  0.250454  3
# 2000-01-04 -0.464137 -1.970613 -0.473362  4
# 2000-01-05  0.097053 -0.033579 -0.465060  5
# 2000-01-06  0.462307  0.545508  0.839077  6
# 2000-01-07 -0.607997  0.210907 -0.563551  7
# 2000-01-08  0.239716  1.017750 -0.481969  8

# %%
df.loc[:, "D"] = np.array([5] * len(df))
df
# Out:
#                    A         B         C  F  D
# 2000-01-01  0.000000  0.000000  1.340927  1  5
# 2000-01-02  1.753779  0.054245 -0.174204  2  5
# 2000-01-03 -0.656894  0.370821  0.250454  3  5
# 2000-01-04 -0.464137 -1.970613 -0.473362  4  5
# 2000-01-05  0.097053 -0.033579 -0.465060  5  5
# 2000-01-06  0.462307  0.545508  0.839077  6  5
# 2000-01-07 -0.607997  0.210907 -0.563551  7  5
# 2000-01-08  0.239716  1.017750 -0.481969  8  5

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  F  D
# 2000-01-01  0.000000  0.000000 -1.340927 -1 -5
# 2000-01-02 -1.753779 -0.054245 -0.174204 -2 -5
# 2000-01-03 -0.656894 -0.370821 -0.250454 -3 -5
# 2000-01-04 -0.464137 -1.970613 -0.473362 -4 -5
# 2000-01-05 -0.097053 -0.033579 -0.465060 -5 -5
# 2000-01-06 -0.462307 -0.545508 -0.839077 -6 -5
# 2000-01-07 -0.607997 -0.210907 -0.563551 -7 -5
# 2000-01-08 -0.239716 -1.017750 -0.481969 -8 -5

# %% [markdown]
# ##Missing data

# %%
df
# Out:
#                    A         B         C  F  D
# 2000-01-01  0.000000  0.000000  1.340927  1  5
# 2000-01-02  1.753779  0.054245 -0.174204  2  5
# 2000-01-03 -0.656894  0.370821  0.250454  3  5
# 2000-01-04 -0.464137 -1.970613 -0.473362  4  5
# 2000-01-05  0.097053 -0.033579 -0.465060  5  5
# 2000-01-06  0.462307  0.545508  0.839077  6  5
# 2000-01-07 -0.607997  0.210907 -0.563551  7  5
# 2000-01-08  0.239716  1.017750 -0.481969  8  5

# %%
df1 = df.reindex(index=index[0:4],columns=list(df.columns)+["E"])
df1.loc[index[0] : index[1], "E"] = 1
df1
# Out:
#                    A         B         C  F  D    E
# 2000-01-01  0.000000  0.000000  1.340927  1  5  1.0
# 2000-01-02  1.753779  0.054245 -0.174204  2  5  1.0
# 2000-01-03 -0.656894  0.370821  0.250454  3  5  NaN
# 2000-01-04 -0.464137 -1.970613 -0.473362  4  5  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C  F  D    E
# 2000-01-01  0.000000  0.000000  1.340927  1  5  1.0
# 2000-01-02  1.753779  0.054245 -0.174204  2  5  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  F  D    E
# 2000-01-01  0.000000  0.000000  1.340927  1  5  1.0
# 2000-01-02  1.753779  0.054245 -0.174204  2  5  1.0
# 2000-01-03 -0.656894  0.370821  0.250454  3  5  5.0
# 2000-01-04 -0.464137 -1.970613 -0.473362  4  5  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      F      D      E
# 2000-01-01  False  False  False  False  False  False
# 2000-01-02  False  False  False  False  False  False
# 2000-01-03  False  False  False  False  False   True
# 2000-01-04  False  False  False  False  False   True

# %% [markdown]
# ##Operations

# %%
df
# Out:
#                    A         B         C  F  D
# 2000-01-01  0.000000  0.000000  1.340927  1  5
# 2000-01-02  1.753779  0.054245 -0.174204  2  5
# 2000-01-03 -0.656894  0.370821  0.250454  3  5
# 2000-01-04 -0.464137 -1.970613 -0.473362  4  5
# 2000-01-05  0.097053 -0.033579 -0.465060  5  5
# 2000-01-06  0.462307  0.545508  0.839077  6  5
# 2000-01-07 -0.607997  0.210907 -0.563551  7  5
# 2000-01-08  0.239716  1.017750 -0.481969  8  5

# %%
df.mean()
# Out:
# A    0.102978
# B    0.024380
# C    0.034039
# F    4.500000
# D    5.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2000-01-01    1.468185
# 2000-01-02    1.726764
# 2000-01-03    1.592876
# 2000-01-04    1.218378
# 2000-01-05    1.919683
# 2000-01-06    2.569378
# 2000-01-07    2.207872
# 2000-01-08    2.755099
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8,8,1], index=index).shift(2)
s
# Out:
# 2000-01-01    NaN
# 2000-01-02    NaN
# 2000-01-03    1.0
# 2000-01-04    3.0
# 2000-01-05    5.0
# 2000-01-06    NaN
# 2000-01-07    6.0
# 2000-01-08    8.0
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C
# 2000-01-01       NaN       NaN       NaN
# 2000-01-02       NaN       NaN       NaN
# 2000-01-03 -2.185118 -0.350812 -1.422109
# 2000-01-04 -3.567090 -3.104624 -3.856980
# 2000-01-05 -5.000358 -6.666904 -4.635500
# 2000-01-06       NaN       NaN       NaN
# 2000-01-07 -5.178273 -4.861522 -6.723475
# 2000-01-08 -8.896600 -9.694298 -6.223311

# %% [markdown]
# ##Plotting

# %%
import matplotlib.pyplot as plt

# %%
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000),index=pd.date_range("1/1/2000",periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
plt.show();

# %%
df = pd.DataFrame(
    np.random.randn(1000,4), index=ts.index, columns=["A","B","C","D"]
)

# %%
df = df.cumsum()

# %%
plt.figure();

# %%
df.plot();
plt.legend(loc='best');

# %% [markdown]
# ## Importing and exporting data

# %%
df.to_excel("example.xlsx",sheet_name='Sheet1') #Sheet_name es el nombre de la hoja

# %%
pd.read_excel("example.xlsx","Sheet1", na_values=["NA"])
# Out:
#     Unnamed: 0          A          B         C         D
# 0   2000-01-01  -0.377764   0.885891 -0.713470  1.249645
# 1   2000-01-02   0.001138   1.154538 -0.860546  3.466671
# 2   2000-01-03  -1.218679   1.148843  0.332636  2.726691
# 3   2000-01-04   0.282326   2.172439  1.461189  2.423054
# 4   2000-01-05   1.834416   1.784595  2.049084  1.852457
# ..         ...        ...        ...       ...       ...
# 995 2002-09-22 -45.202124 -39.033138  2.136208 -5.849337
# 996 2002-09-23 -45.329542 -39.229431  0.877395 -6.729654
# 997 2002-09-24 -44.217607 -38.635954  0.961738 -7.450612
# 998 2002-09-25 -43.988762 -38.016456  1.201730 -8.805636
# 999 2002-09-26 -42.417049 -37.708184  0.001456 -9.857482
#
# [1000 rows x 5 columns]

# %%
df.to_csv("foo.csv")

# %%
pd.read_csv("foo.csv")
# Out:
#      Unnamed: 0          A          B         C         D
# 0    2000-01-01  -0.377764   0.885891 -0.713470  1.249645
# 1    2000-01-02   0.001138   1.154538 -0.860546  3.466671
# 2    2000-01-03  -1.218679   1.148843  0.332636  2.726691
# 3    2000-01-04   0.282326   2.172439  1.461189  2.423054
# 4    2000-01-05   1.834416   1.784595  2.049084  1.852457
# ..          ...        ...        ...       ...       ...
# 995  2002-09-22 -45.202124 -39.033138  2.136208 -5.849337
# 996  2002-09-23 -45.329542 -39.229431  0.877395 -6.729654
# 997  2002-09-24 -44.217607 -38.635954  0.961738 -7.450612
# 998  2002-09-25 -43.988762 -38.016456  1.201730 -8.805636
# 999  2002-09-26 -42.417049 -37.708184  0.001456 -9.857482
#
# [1000 rows x 5 columns]
