# %% [markdown]
# <a href="https://colab.research.google.com/github/OmarFloresPTY/my-google-colabs/blob/master/02_Pandas_annotations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10 minutes to pandas 🐼📚🐍

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Object Creation

# %%
s = pd.Series([1,3,4,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    4.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101',periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD')) #np.random.randn(fila,columna) genera una matriz fila x columna de 0 y una desviación estándar de 1
# Out:
#                    A         B         C         D
# 2013-01-01  1.234692  2.912774  0.750037 -1.218876
# 2013-01-02  0.852987  0.692316  0.633768  1.265729
# 2013-01-03  0.400355  0.367191 -1.283545 -1.457538
# 2013-01-04 -1.501198 -0.510490 -0.916297  0.525405
# 2013-01-05  0.025758  1.433713  1.109606  0.826190
# 2013-01-06  0.113586 -0.944401 -0.694295 -0.349092

# %%
pd.DataFrame(np.random.randint(0,20,size=(5,5)),index=[i for i in range(5,10)],columns=['A','B','C','D','E'])
# Out:
#     A   B   C   D   E
# 5   4  13   8  12   0
# 6   8  17   0   0   5
# 7  12  10  12   9   9
# 8  12   7   9   3  17
# 9   0  14   0  17  16

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# ## Viewing Data

# %%
index = pd.date_range("1/1/2000", periods=8)
df = pd.DataFrame(np.random.randn(8, 3), index=index, columns=["A", "B", "C"])
df
# Out:
#                    A         B         C
# 2000-01-01  0.962411  0.837590 -0.120217
# 2000-01-02 -0.483843  0.403455 -0.935541
# 2000-01-03 -0.088735 -0.884590 -0.033246
# 2000-01-04 -1.430268  1.355871 -1.116256
# 2000-01-05  0.534747 -0.416010 -1.218709
# 2000-01-06  0.268901 -0.468009 -1.413282
# 2000-01-07  0.960613 -0.096943  0.182109
# 2000-01-08  1.318437  0.946907 -0.035964

# %%
df.head()
# Out:
#                    A         B         C
# 2000-01-01  1.306585  1.866377 -0.569039
# 2000-01-02  0.340853  0.705448 -0.103779
# 2000-01-03 -1.153509  0.780356  0.541386
# 2000-01-04  1.037473  1.573459 -0.052101
# 2000-01-05 -1.235916 -0.196889 -0.217416

# %%
df.tail(3)
# Out:
#                    A         B         C
# 2000-01-06 -0.149585 -0.016882 -0.722609
# 2000-01-07 -1.066007 -0.686150  0.306349
# 2000-01-08 -0.544149 -0.183832  0.486914

# %%
df.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %% [markdown]
# ¡IMPORTANTE! 🚨 La conversión de un dataFrame a un objeto numpy, NO incluye los índices o columnas.

# %%
df.to_numpy()
# Out:
# array([[ 1.30658525,  1.86637739, -0.56903902],
#        [ 0.34085294,  0.70544835, -0.10377926],
#        [-1.15350933,  0.78035569,  0.54138559],
#        [ 1.03747308,  1.57345946, -0.05210125],
#        [-1.23591619, -0.19688857, -0.21741615],
#        [-0.14958511, -0.0168823 , -0.72260912],
#        [-1.0660069 , -0.68615024,  0.30634859],
#        [-0.54414872, -0.18383224,  0.48691359]])

# %%
print(type(df))
print(type(df.to_numpy()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C
# count  8.000000  8.000000  8.000000
# mean   0.255283  0.209784 -0.586388
# std    0.903315  0.795637  0.643993
# min   -1.430268 -0.884590 -1.413282
# 25%   -0.187512 -0.429010 -1.141869
# 50%    0.401824  0.153256 -0.527879
# 75%    0.961063  0.864919 -0.035284
# max    1.318437  1.355871  0.182109

# %%
df.T
# Out:
#    2000-01-01  2000-01-02  2000-01-03  2000-01-04  2000-01-05  2000-01-06  \
# A    0.962411   -0.483843   -0.088735   -1.430268    0.534747    0.268901
# B    0.837590    0.403455   -0.884590    1.355871   -0.416010   -0.468009
# C   -0.120217   -0.935541   -0.033246   -1.116256   -1.218709   -1.413282
#
#    2000-01-07  2000-01-08
# A    0.960613    1.318437
# B   -0.096943    0.946907
# C    0.182109   -0.035964

# %%
df
# Out:
#                    A         B         C
# 2000-01-01  0.962411  0.837590 -0.120217
# 2000-01-02 -0.483843  0.403455 -0.935541
# 2000-01-03 -0.088735 -0.884590 -0.033246
# 2000-01-04 -1.430268  1.355871 -1.116256
# 2000-01-05  0.534747 -0.416010 -1.218709
# 2000-01-06  0.268901 -0.468009 -1.413282
# 2000-01-07  0.960613 -0.096943  0.182109
# 2000-01-08  1.318437  0.946907 -0.035964

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                    C         B         A
# 2000-01-01 -0.120217  0.837590  0.962411
# 2000-01-02 -0.935541  0.403455 -0.483843
# 2000-01-03 -0.033246 -0.884590 -0.088735
# 2000-01-04 -1.116256  1.355871 -1.430268
# 2000-01-05 -1.218709 -0.416010  0.534747
# 2000-01-06 -1.413282 -0.468009  0.268901
# 2000-01-07  0.182109 -0.096943  0.960613
# 2000-01-08 -0.035964  0.946907  1.318437

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C
# 2000-01-03 -0.088735 -0.884590 -0.033246
# 2000-01-06  0.268901 -0.468009 -1.413282
# 2000-01-05  0.534747 -0.416010 -1.218709
# 2000-01-07  0.960613 -0.096943  0.182109
# 2000-01-02 -0.483843  0.403455 -0.935541
# 2000-01-01  0.962411  0.837590 -0.120217
# 2000-01-08  1.318437  0.946907 -0.035964
# 2000-01-04 -1.430268  1.355871 -1.116256

# %% [markdown]
# ## Getting
